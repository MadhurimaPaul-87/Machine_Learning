# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhurimaPaul-87/Machine_Learning/blob/main/BasicTensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import libraries**

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# **Define and compile the neural network**

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# **Train the Neural Network**

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 444ms/step - loss: 58.7302
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 46.2061
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 36.3527
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 28.6006
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 22.5016
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 17.7032
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 13.9280
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 10.9579
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 8.6211
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 6.7827
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.3363
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1984
# ...

# %% [markdown]
# **Predict**

# %%
print(model.predict([10.0]))
# Out:
# [[31.000134]]
