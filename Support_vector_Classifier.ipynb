# %% [markdown]
# <a href="https://colab.research.google.com/github/MadhurimaPaul-87/Machine_Learning/blob/main/Support_vector_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Importing dataset**

# %%
iris=datasets.load_iris()

# %% [markdown]
# **Getting independent and dependent variable**

# %%
# we only take first two features (sepal_length,sepal_width)
X= iris.data[ : , :2]
# Target variable "Species"
y= iris.target

# %% [markdown]
# **Visualizing Classification Region**

# %% [markdown]
# The purpose of meshgrid is to create a rectangular grid out of an array of x values and y values

# %%
##Create a mesh-grid to show the classification regions

#Defining limit for the x-axis
x_min,x_max = X[:,0].min()-1 , X[:,0].max()+1

#Defining limit for the y-axis
y_min,y_max = X[:,1].min()-1 , X[:,1].max()+1

#0.01 step size with respect to x limit
h= (x_max / x_min)/100

#Defining the mesh grid with above parameter
xx,yy=np.meshgrid(np.arange(x_min,x_max,h) , np.arange(y_min,y_max,h))

# %% [markdown]
# **Plotting the regions**

# %% [markdown]
# **1.Instantiating SVC(Default)**

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(X,y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# **Plotting**

# %%
plt.figure(figsize=(5,5), dpi=80)
Z= svc.predict(np.c_[xx.ravel(),yy.ravel()])
Z=Z.reshape(xx.shape)
plt.contourf(xx,yy,Z,cmap=plt.cm.Paired,alpha=0.7)

plt.scatter(X[:,0],X[:,1], c=y, cmap=plt.cm.Paired)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.xlim(xx.min(),xx.max())
plt.title("Default SVM")
plt.show()

# %% [markdown]
# **2.Linear SVM**

# %%
svc=SVC(kernel='linear')
svc.fit(X,y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# **Plotting**

# %%
plt.figure(figsize=(5,5), dpi=80)
Z= svc.predict(np.c_[xx.ravel(),yy.ravel()])
Z=Z.reshape(xx.shape)
plt.contourf(xx,yy,Z,cmap=plt.cm.Paired,alpha=0.7)

plt.scatter(X[:,0],X[:,1], c=y, cmap=plt.cm.Paired)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.xlim(xx.min(),xx.max())
plt.title("Linear SVM")
plt.show()

# %% [markdown]
# **3.SVM with Polynomial kernel**

# %%
svc=SVC(kernel="poly")
svc.fit(X,y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# **Plotting**

# %%
plt.figure(figsize=(5,5), dpi=80)
Z= svc.predict(np.c_[xx.ravel(),yy.ravel()])
Z=Z.reshape(xx.shape)
plt.contourf(xx,yy,Z,cmap=plt.cm.Paired,alpha=0.7)

plt.scatter(X[:,0],X[:,1], c=y, cmap=plt.cm.Paired)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.xlim(xx.min(),xx.max())
plt.title("Default Polynomial SVM")
plt.show()
